# %%
import pandas as pd

# Load original tabular dataset
df = pd.read_excel("../data/tabular/PCOS.xlsx")

# Drop target column
X = df.drop(columns=["PCOS (Y/N)"])

# Take one realistic PCOS-positive example
sample = X.iloc[[10]]  # any row index is fine

# Save as sample input
sample.to_csv(
    "../data/sample_inputs/sample_tabular_patient.csv",
    index=False
)

print("✅ Sample tabular patient created")
# Out:
# ✅ Sample tabular patient created

# %%
import pandas as pd

df = pd.read_excel("../data/tabular/PCOS.xlsx")

# This must match your training step
X = df.drop(columns=["PCOS"])

print(list(X.columns))
